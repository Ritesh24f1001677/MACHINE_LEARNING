# %% [markdown]
# <a href="https://colab.research.google.com/github/Ritesh24f1001677/MACHINE_LEARNING/blob/main/Week4_MLP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Regression Model

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
df=pd.read_csv('/content/Week3_GA_dataset.csv')

# %%
df.head()
# Out:
#     V1    V2       V3    V4        V5 Target
# 0  2.0  50.0  12500.0  98.0  NEGATIVE    YES
# 1  0.0  13.0   3250.0  28.0  NEGATIVE    YES
# 2    ?     ?   4000.0  35.0  NEGATIVE    YES
# 3    ?  20.0   5000.0  45.0  NEGATIVE    YES
# 4  1.0  24.0   6000.0  77.0  NEGATIVE     NO

# %%
X_train=df[['V1','V2','V3','V4','V5']]
le=LabelEncoder()
Y_train=le.fit_transform(df['Target'])

# %%
from sklearn.dummy import DummyRegressor
dummy_Regr=DummyRegressor(strategy='mean')
dummy_Regr.fit(X_train,Y_train)
# Out:
# DummyRegressor()

# %%
dummy_Regr.predict(X_train)
# Out:
# array([0.23796791, 0.23796791, 0.23796791, 0.23796791, 0.23796791,
#        0.23796791, 0.23796791, 0.23796791, 0.23796791, 0.23796791,
#        0.23796791, 0.23796791, 0.23796791, 0.23796791, 0.23796791,
#        0.23796791, 0.23796791, 0.23796791, 0.23796791, 0.23796791,
#        0.23796791, 0.23796791, 0.23796791, 0.23796791, 0.23796791,
#        0.23796791, 0.23796791, 0.23796791, 0.23796791, 0.23796791,
#        0.23796791, 0.23796791, 0.23796791, 0.23796791, 0.23796791,
#        0.23796791, 0.23796791, 0.23796791, 0.23796791, 0.23796791,
#        0.23796791, 0.23796791, 0.23796791, 0.23796791, 0.23796791,
#        0.23796791, 0.23796791, 0.23796791, 0.23796791, 0.23796791,
#        0.23796791, 0.23796791, 0.23796791, 0.23796791, 0.23796791,
#        0.23796791, 0.23796791, 0.23796791, 0.23796791, 0.23796791,
#        0.23796791, 0.23796791, 0.23796791, 0.23796791, 0.23796791,
#        0.23796791, 0.23796791, 0.23796791, 0.23796791, 0.23796791,
# ...

# %% [markdown]
# # How is the Linear Regression model trained

# %%
from sklearn.linear_model import LinearRegression

# %%
linear_regressor=LinearRegression()

# %%
linear_regressor  # Normal Equations
# Out:
# LinearRegression()

# %%
from sklearn.linear_model import SGDRegressor

# %%
linearRegSGD=SGDRegressor() # Iterative Optimizations

# %%
linearRegSGD
# Out:
# SGDRegressor()

# %%
# X_train  is a feature matrix
# Y_train is a label vector

# %% [markdown]
# # SGD Regressor Estimators
#  1. Stochastic gradient Descent
#  2. Uses for large training set up (>10 k)
#  3. greater control on the optimizations
#  4. Loss='squared error'
#  5. Loss='huber
#  6. Penalty ='l1'
#  7. Penalty='L2'
#  8. Penalty='elasticnet'
#
#
#  # SGDRegressor
#  1. learning_Rate='constant'
#  2. learning_Rate='optimal'
#  3. learning_Rate='invascaling'
#  4. learning_Rate='adaptive'
#
#  5. early_stopping='True'
#  6. early_stopping='False'
#
#  # We can use Random Seed

# %%
from sklearn.linear_model import SGDRegressor

# %%
linear_regressor_s=SGDRegressor(random_state=42)

# %% [markdown]
# # Scaling the SGDRegressor

# %%
from sklearn.linear_model import SGDRegressor
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
sgd=Pipeline([
    ('feature_scaling',StandardScaler()),
    ('sgd_regressor',SGDRegressor())
])

# %%
sgd
# Out:
# Pipeline(steps=[('feature_scaling', StandardScaler()),
#                 ('sgd_regressor', SGDRegressor())])

# %% [markdown]
# # How to use set learning rate in SGDRegressor
#
# 1. learning_rate='constant'
# 2. learning_rate='invascaling'
# 3. learning_rate='adaptive'?
#
#
# # What is default Scaling?
#
# 1. learning_Rate='invascaling'
# 2. eta0=le-2
# 3. power_t=0.25

# %%
from sklearn.linear_model import SGDRegressor
linear_regressor_sg =SGDRegressor(learning_rate='adaptive',eta0=1e-2)

# %%
linear_regressor_sg
# Out:
# SGDRegressor(learning_rate='adaptive')

# %%
from sklearn.linear_model import SGDRegressor

# %%
linear_regressor_sgd=SGDRegressor(max_iter=100)

# %%
linear_regressor_sgd
# Out:
# SGDRegressor(max_iter=100)

# %%
from sklearn.linear_model import SGDRegressor
linear_regressor_stop=SGDRegressor(loss='squared_error',
                                   early_stopping=True,
                                   max_iter=500,
                                   tol=1e-3,
                                   validation_fraction=0.2,
                                   n_iter_no_change=5,
                                   average=True) # we can also use average=10 , wo it will check 10 samples

# %%
linear_regressor_stop
# Out:
# SGDRegressor(average=True, early_stopping=True, max_iter=500,
#              validation_fraction=0.2)

# %% [markdown]
# # How do we initialize the SGD with the weight vectors of the previous run

# %%
linear_regressor_stop=SGDRegressor(loss='squared_error',
                                   early_stopping=True,
                                   max_iter=500,
                                   tol=1e-3,
                                   validation_fraction=0.2,
                                   n_iter_no_change=5,
                                   average=True,
                                   warm_start=True) # we can also use average=10 , wo it will check 10 samples

# %%
linear_regressor_stop
# Out:
# SGDRegressor(average=True, early_stopping=True, max_iter=500,
#              validation_fraction=0.2, warm_start=True)

# %% [markdown]
# # how to monitor the SGD loss iteration after iteration

# %%
import numpy as np
sgd=SGDRegressor(max_iter=1, tol=-np.inf, warm_start=True, penalty=None, learning_rate="constant",eta0=0.005)

# %%
sgd
# Out:
# SGDRegressor(eta0=0.005, learning_rate='constant', max_iter=1, penalty=None,
#              tol=-inf, warm_start=True)

# %%
'''for epochin range(1000):
  #sgd.fit(X_train,y_train)
  y_val_predict=sgd.predict(X_val)
  val_error=mean_squared_error(y_val, y_val_predict)'''
# Out:
# 'for epochin range(1000):\n  #sgd.fit(X_train,y_train)\n  y_val_predict=sgd.predict(X_val)\n  val_error=mean_squared_error(y_val, y_val_predict)'

# %% [markdown]
# # Model Inspection
#
# 1. How to access the weight of the trained linear regression model
#
# - linear_regressor.coef_
# - linear_regressor.intercept_
#
# # How to make a Prediction on a new data in Linear Regression Model
# - linear_regressor.predict(X_test)

# %%
import pandas as pd
import numpy as np

# %%
from sklearn.datasets import load_diabetes

# %%
diabetes=load_diabetes()

# %%
df=pd.DataFrame(diabetes.data, columns=diabetes.feature_names)
#df['target'] = diabetes.target
#df

# %%
df.head()
# Out:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
#
#          s4        s5        s6
# 0 -0.002592  0.019907 -0.017646
# 1 -0.039493 -0.068332 -0.092204
# 2 -0.002592  0.002861 -0.025930
# 3  0.034309  0.022688 -0.009362
# 4 -0.002592 -0.031988 -0.046641

# %%
df
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 0    0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1   -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2    0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3   -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4    0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
# ..        ...       ...       ...       ...       ...       ...       ...
# 437  0.041708  0.050680  0.019662  0.059744 -0.005697 -0.002566 -0.028674
# 438 -0.005515  0.050680 -0.015906 -0.067642  0.049341  0.079165 -0.028674
# 439  0.041708  0.050680 -0.015906  0.017293 -0.037344 -0.013840 -0.024993
# 440 -0.045472 -0.044642  0.039062  0.001215  0.016318  0.015283 -0.028674
# 441 -0.045472 -0.044642 -0.073030 -0.081413  0.083740  0.027809  0.173816
#
#            s4        s5        s6
# 0   -0.002592  0.019907 -0.017646
# ...

# %%
df.isnull().sum()
# Out:
# age    0
# sex    0
# bmi    0
# bp     0
# s1     0
# s2     0
# s3     0
# s4     0
# s5     0
# s6     0
# dtype: int64

# %%
df['target'] = diabetes.target

# %%
df
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 0    0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1   -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2    0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3   -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4    0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
# ..        ...       ...       ...       ...       ...       ...       ...
# 437  0.041708  0.050680  0.019662  0.059744 -0.005697 -0.002566 -0.028674
# 438 -0.005515  0.050680 -0.015906 -0.067642  0.049341  0.079165 -0.028674
# 439  0.041708  0.050680 -0.015906  0.017293 -0.037344 -0.013840 -0.024993
# 440 -0.045472 -0.044642  0.039062  0.001215  0.016318  0.015283 -0.028674
# 441 -0.045472 -0.044642 -0.073030 -0.081413  0.083740  0.027809  0.173816
#
#            s4        s5        s6  target
# ...

# %%
df['target']
# Out:
# 0      151.0
# 1       75.0
# 2      141.0
# 3      206.0
# 4      135.0
#        ...
# 437    178.0
# 438    104.0
# 439    132.0
# 440    220.0
# 441     57.0
# Name: target, Length: 442, dtype: float64

# %%
from sklearn.linear_model import LinearRegression, Lasso, Ridge
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import VotingRegressor
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor, VotingRegressor, AdaBoostRegressor

# %%
lr=LinearRegression()

# %%
lr
# Out:
# LinearRegression()

# %%
X = df.drop('target', axis=1)
y = df['target']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train, y_test=train_test_split(X,y, test_size=0.2, shuffle=True,random_state=42)

# %%
# So basically i am trying to split the datasets and then i will get total 4 datasets

# %%
X_train.shape
# Out:
# (353, 10)

# %%
X_test.shape
# Out:
# (89, 10)

# %%
X_train.head()
# this is the feature variable datasets.......
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 17   0.070769  0.050680  0.012117  0.056301  0.034206  0.049416 -0.039719
# 66  -0.009147  0.050680 -0.018062 -0.033213 -0.020832  0.012152 -0.072854
# 137  0.005383 -0.044642  0.049840  0.097615 -0.015328 -0.016345 -0.006584
# 245 -0.027310 -0.044642 -0.035307 -0.029770 -0.056607 -0.058620  0.030232
# 31  -0.023677 -0.044642 -0.065486 -0.081413 -0.038720 -0.053610  0.059685
#
#            s4        s5        s6
# 17   0.034309  0.027364 -0.001078
# 66   0.071210  0.000272  0.019633
# 137 -0.002592  0.017036 -0.013504
# 245 -0.039493 -0.049872 -0.129483
# 31  -0.076395 -0.037129 -0.042499

# %%
X_test.head()
# this is the feature varable test datasets...........
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 287  0.045341 -0.044642 -0.006206 -0.015999  0.125019  0.125198  0.019187
# 211  0.092564 -0.044642  0.036907  0.021872 -0.024960 -0.016658  0.000779
# 72   0.063504  0.050680 -0.004050 -0.012556  0.103003  0.048790  0.056003
# 321  0.096197 -0.044642  0.051996  0.079265  0.054845  0.036577 -0.076536
# 73   0.012648  0.050680 -0.020218 -0.002228  0.038334  0.053174 -0.006584
#
#            s4        s5        s6
# 287  0.034309  0.032432 -0.005220
# 211 -0.039493 -0.022517 -0.021788
# 72  -0.002592  0.084492 -0.017646
# 321  0.141322  0.098648  0.061054
# 73   0.034309 -0.005142 -0.009362

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
lr.score(X_train,y_train)
# Out:
# 0.5279193863361498

# %%
lr.score(X_test,y_test)
# Out:
# 0.4526027629719195

# %%
# It gives the line which is having based and biased
lr.coef_
# Out:
# array([  37.90402135, -241.96436231,  542.42875852,  347.70384391,
#        -931.48884588,  518.06227698,  163.41998299,  275.31790158,
#         736.1988589 ,   48.67065743])

# %%
lr.intercept_
# Out:
# np.float64(151.34560453985995)

# %%
X_train @ lr.coef_.T + lr.intercept_
# Out:
# 17     184.699989
# 66     151.946480
# 137    239.232818
# 245    105.018618
# 31      65.032987
#           ...
# 106     69.015131
# 270    193.983511
# 348    132.929730
# 435    119.186044
# 102    141.374614
# Length: 353, dtype: float64

# %%
lr.get_params()
# Out:
# {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': False}

# %%
dt=DecisionTreeRegressor(min_samples_leaf=5,max_depth=3)

# %%
dt
# Out:
# DecisionTreeRegressor(max_depth=3, min_samples_leaf=5)

# %%
dt.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor(max_depth=3, min_samples_leaf=5)

# %%
dt.score(X_train,y_train)
# Out:
# 0.5163557610794234

# %%
dt.score(X_test,y_test)
# Out:
# 0.4159289074356103

# %%
adaboost=AdaBoostRegressor(random_state=42,loss='square')

# %%
adaboost.get_params()
# Out:
# {'estimator': None,
#  'learning_rate': 1.0,
#  'loss': 'squared_error',
#  'n_estimators': 50,
#  'random_state': 42}

# %%
adaboost.fit(X_train,y_train)
# Out:
# AdaBoostRegressor(loss='square', random_state=42)

# %%
adaboost.score(X_train,y_train)
# Out:
# 0.644351589223966

# %%
adaboost.score(X_test,y_test)
# Out:
# 0.45588984925779075

# %%
ri=Ridge()

# %%
ri.fit(X_train,y_train)
# Out:
# Ridge()

# %%
ri.score(X_train,y_train)
# Out:
# 0.4424027835503952

# %%
ri.score(X_test,y_test)
# Out:
# 0.41915292635986545

# %%
ls=Lasso()

# %%
ls.fit(X_train,y_train)
# Out:
# Lasso()

# %%
ls.score(X_train,y_train)
# Out:
# 0.3646309911295581

# %%
rf=RandomForestRegressor()

# %%
rf.fit(X_train,y_train)
# Out:
# RandomForestRegressor()

# %%
rf.score(X_train,y_train)
# Out:
# 0.9190836493801133

# %%
rf.score(X_test,y_test)
# Out:
# 0.4230748884042713

# %%
from sklearn.preprocessing import PolynomialFeatures
pf=PolynomialFeatures(degree=2).set_output(transform='pandas')

# %%
pf.fit_transform(X_train)
# Out:
#        1       age       sex       bmi        bp        s1        s2  \
# 17   1.0  0.070769  0.050680  0.012117  0.056301  0.034206  0.049416
# 66   1.0 -0.009147  0.050680 -0.018062 -0.033213 -0.020832  0.012152
# 137  1.0  0.005383 -0.044642  0.049840  0.097615 -0.015328 -0.016345
# 245  1.0 -0.027310 -0.044642 -0.035307 -0.029770 -0.056607 -0.058620
# 31   1.0 -0.023677 -0.044642 -0.065486 -0.081413 -0.038720 -0.053610
# ..   ...       ...       ...       ...       ...       ...       ...
# 106  1.0 -0.096328 -0.044642 -0.076264 -0.043542 -0.045599 -0.034821
# 270  1.0  0.005383  0.050680  0.030440  0.083844 -0.037344 -0.047347
# 348  1.0  0.030811 -0.044642 -0.020218 -0.005670 -0.004321 -0.029497
# 435  1.0 -0.012780 -0.044642 -0.023451 -0.040099 -0.016704  0.004636
# 102  1.0 -0.092695 -0.044642  0.028284 -0.015999  0.036958  0.024991
#
#            s3        s4        s5  ...      s3^2     s3 s4     s3 s5  \
# ...

# %%
pf.get_feature_names_out()
# Out:
# array(['1', 'age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6',
#        'age^2', 'age sex', 'age bmi', 'age bp', 'age s1', 'age s2',
#        'age s3', 'age s4', 'age s5', 'age s6', 'sex^2', 'sex bmi',
#        'sex bp', 'sex s1', 'sex s2', 'sex s3', 'sex s4', 'sex s5',
#        'sex s6', 'bmi^2', 'bmi bp', 'bmi s1', 'bmi s2', 'bmi s3',
#        'bmi s4', 'bmi s5', 'bmi s6', 'bp^2', 'bp s1', 'bp s2', 'bp s3',
#        'bp s4', 'bp s5', 'bp s6', 's1^2', 's1 s2', 's1 s3', 's1 s4',
#        's1 s5', 's1 s6', 's2^2', 's2 s3', 's2 s4', 's2 s5', 's2 s6',
#        's3^2', 's3 s4', 's3 s5', 's3 s6', 's4^2', 's4 s5', 's4 s6',
#        's5^2', 's5 s6', 's6^2'], dtype=object)

# %%
from sklearn.pipeline import Pipeline

# %%
pipe=Pipeline(steps=[(
    'poly',PolynomialFeatures(degree=2)),('model',RandomForestRegressor(random_state=42))])

# %%
pipe
# Out:
# Pipeline(steps=[('poly', PolynomialFeatures()),
#                 ('model', RandomForestRegressor(random_state=42))])

# %%
pipe.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('poly', PolynomialFeatures()),
#                 ('model', RandomForestRegressor(random_state=42))])

# %%
pipe.score(X_train,y_train)
# Out:
# 0.9190466414240279

# %%
pipe.score(X_test,y_test)
# Out:
# 0.4613920424355905

# %%
pipe1=Pipeline(steps=[(
    'poly',PolynomialFeatures(degree=2)),('model',Ridge())])

# %%
pipe1
# Out:
# Pipeline(steps=[('poly', PolynomialFeatures()), ('model', Ridge())])

# %%
r1=LinearRegression()
r2=RandomForestRegressor(n_estimators=10,random_state=42)
r3=KNeighborsRegressor()

# %%
er=VotingRegressor([('lr',r1),('rf',r2),('r3',r3)],weights=[2,5,1])

# %%
er.fit(X_train,y_train)
# Out:
# VotingRegressor(estimators=[('lr', LinearRegression()),
#                             ('rf',
#                              RandomForestRegressor(n_estimators=10,
#                                                    random_state=42)),
#                             ('r3', KNeighborsRegressor())],
#                 weights=[2, 5, 1])

# %%
er.score(X_train,y_train)
# Out:
# 0.8329853219338009

# %%
er.score(X_test,y_test)
# Out:
# 0.4755467740433519

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
from sklearn.preprocessing import MinMaxScaler
