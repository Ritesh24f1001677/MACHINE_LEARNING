# %% [markdown]
# <a href="https://colab.research.google.com/github/Ritesh24f1001677/MACHINE_LEARNING/blob/main/Week3_TA_Sessioin_and_GA3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Data Preprocessing Exercises
#
# **Dataset link**: https://drive.google.com/file/d/1JYQ_dmlNobUgaRc-xwjsIALurJiW6eHg/view?usp=sharing

# %%
df = pd.read_csv('/content/data (2).csv')

# %%
df.head()
# Out:
#                             customer_id               name  age  gender  \
# 0  4d623250-b704-4df8-aea2-5403458a1d6e        Sean Nelson   41       F
# 1  e5593c2b-1ed8-4fe8-be82-acced82f9711         Eddie Wood   38  Female
# 2  7240c499-1c3d-4188-8b12-76c515aff931     Abigail Graham   11       M
# 3  43c7001d-4c6d-4011-aa02-e9b57c0e3944  Jessica Contreras   40     NaN
# 4  4fb0f886-7e67-4982-bfe0-959272cece1b        Kelly Olson   20  Female
#
#                     email     join_date last_purchase  total_spent  \
# 0  tylersmith@example.org  Dec 19, 2020    2025-04-02   238.517142
# 1       xreed@example.net    30/10/2021    2024-12-25    93.126377
# 2  cartersara@example.com  May 03, 2022    2025-05-10   873.017713
# 3    fsalazar@example.org  Aug 03, 2021           NaN   401.703726
# 4    robert21@example.org  Apr 05, 2024    2025-05-07  1198.186419
#
#    purchase_count  country               city postal_code subscription_type  \
# ...

# %% [markdown]
# ### Ques. What is the shape of the dataset?

# %%
# solution
df.shape
# Out:
# (10000, 20)

# %% [markdown]
# ### Ques. How many duplicates rows are there?

# %%
df['customer_id'].nunique()
# Out:
# 10000

# %%
# solution
df_new = df.drop('customer_id', axis=1)
df_new.head(2)
# Out:
#           name  age  gender                   email     join_date  \
# 0  Sean Nelson   41       F  tylersmith@example.org  Dec 19, 2020
# 1   Eddie Wood   38  Female       xreed@example.net    30/10/2021
#
#   last_purchase  total_spent  purchase_count  country               city  \
# 0    2025-04-02   238.517142            51.0  Germany  Port Michaelmouth
# 1    2024-12-25    93.126377            31.0      USA            Brig...
#
#   postal_code subscription_type  credit_score is_active payment_method  \
# 0       06803         Corporate           663      True            NaN
# 1       64245               NaN           656         N         PayPal
#
#   preferred_category  avg_session_duration device_type campaign_response
# 0          Groceries           1066.626690      TABLET               NaN
# 1           Clothing            327.762945      mobile                no

# %%
df_new.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### Ques. Remove redundancy in `gender`, `campaign_response`, `device_type` and `is_active`.

# %%
# solution
df['gender'].unique()
# Out:
# array(['F', 'Female', 'M', nan, 'male', 'female', 'Male'], dtype=object)

# %%
map_gender = {
    'Male': 'M',
    'male': 'M',
    'Female': 'F',
    'female': 'F'
}

df['gender'] = df['gender'].replace(map_gender)

# %%
df['gender'].unique()
# Out:
# array(['F', 'M', nan], dtype=object)

# %%
df['campaign_response'].unique()
# Out:
# array([nan, 'no', 'No', 'YES', 'Yes'], dtype=object)

# %%
map_cp = {
    'Yes': 'yes',
    'YES': 'yes',
    'No': 'no',
    'NO': 'no'
}

df['campaign_response'] = df['campaign_response'].replace(map_cp)

# %%
df['campaign_response'].unique()
# Out:
# array([nan, 'no', 'yes'], dtype=object)

# %%
df['device_type'].unique()
# Out:
# array(['TABLET', 'mobile', 'Mobile', 'desktop', 'Desktop'], dtype=object)

# %%
df['device_type'] = df['device_type'].str.lower()

# %%
df['device_type'].unique()
# Out:
# array(['tablet', 'mobile', 'desktop'], dtype=object)

# %%
df['is_active'].unique()
# Out:
# array(['True', 'N', 'Yes', 'No', 'False', 'Y'], dtype=object)

# %%
map_active = {
    'Yes': 'yes',
    'YES': 'yes',
    'No': 'no',
    'NO': 'no',
    'False': 'no',
    'True': 'yes',
    'N': 'no',
    'Y': 'yes',

}

df['is_active'] = df['is_active'].replace(map_active)

# %%
df['is_active'].unique()
# Out:
# array(['yes', 'no'], dtype=object)

# %% [markdown]
# ### Ques. Extract the day and month from `join_date` and `last_purchase`. Drop the original `join_date` and `last_purchase` columns.

# %%
# Solution

# %% [markdown]
# ## Imputation
#
# For below tasks, try using `Pipeline` and `ColumnTransformer`. Use the below rule for imputing null values:
#
# * `postal_code`: Imputing with mode (most common postal code)
# * `preferred_category` : Impute with mode (most common category)
# * `campaign_response` : Create a new category as 'missing_response'.
# * `subscription_type` : Impute with mode (most common category)
# * `avg_session_duration`: Impute with median
# * `payment_method`: Impute with mode (most common category)
# * `country`: Impute with mode (most common category)
# * `gender`: Impute with mode (most common category)
# * `purchase_count`: Impute with 0
# * `age`: Impute with median

# %%
from sklearn.impute import SimpleImputer

# %% [markdown]
# *most_freq* : postal_code, preferred_category, subscription_type, payment_method, country, gender
#
# *median* : avg_session_duration, age
#
# *const* : purchase_count, campaign_response

# %%
from sklearn.compose import ColumnTransformer

# %%
# Solution
impute_tf = [('mode_imputer', SimpleImputer(strategy='most_frequent'), ['postal_code', 'preferred_category', 'subscription_type',
                                                                        'payment_method', 'country', 'gender']),

             ('median_imputer', SimpleImputer(strategy='median'), ['avg_session_duration', 'age']),

             ('const_imputer', SimpleImputer(strategy='constant', fill_value=0), ['purchase_count', 'campaign_response'])]

ct = ColumnTransformer(transformers=impute_tf, remainder='passthrough', verbose_feature_names_out=False).set_output(transform='pandas')
ct
# Out:
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('mode_imputer',
#                                  SimpleImputer(strategy='most_frequent'),
#                                  ['postal_code', 'preferred_category',
#                                   'subscription_type', 'payment_method',
#                                   'country', 'gender']),
#                                 ('median_imputer',
#                                  SimpleImputer(strategy='median'),
#                                  ['avg_session_duration', 'age']),
#                                 ('const_imputer',
#                                  SimpleImputer(fill_value=0,
#                                                strategy='constant'),
#                                  ['purchase_count', 'campaign_response'])],
#                   verbose_feature_names_out=False)

# %% [markdown]
# ## Scaling and encoding:
#
# For below tasks, try using `Pipeline`, `FeatureUnion` and `ColumnTransformer`. After encoding all categorical variables, scale the encoded ones with `StandardScaler`.
#
#
# Use the below rule for encoding categorical features:
#
# * Remove `customer_id`, `email`, `name`, `city` and `postal_code` columns.
# * One Hot Encode `country`, `subscription_type`, `payment_method`, `preferred_category`, `device_type`
# * Ordinal Encode: `gender`, `is_active`, `campaign_response`
#
#
# Use the below rule for scaling numerical features:
#
# * `StandardScaler`: `age`, '`total_spent`, `avg_session_duration`
# * `MinMaxScaler` : `purchase_count`
# * `RobustScaler` : `credit_score`

# %%
# Solution
from sklearn.pipeline import Pipeline,  FeatureUnion
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder, StandardScaler, MinMaxScaler, RobustScaler

# %%
df=df.drop(['customer_id','email','name','city','postal_code'],axis=1)

# %%
encode_tf=[
    ('ohe',OneHotEncoder(sparse_output=False), ['country','subscription_type','payment_method','preferred_category','device_type']),
    ('oe',OrdinalEncoder(),['gender', 'is_active','campaign_response'])
]
encode_ct=ColumnTransformer(transformers=encode_tf, remainder='drop', verbose_feature_names_out=False).set_output(transform='pandas')

# %%
pipe1=Pipeline(steps=[('encoding',encode_ct),
                      ('scaling',StandardScaler())]).set_output(transform='pandas')

# %%
pipe1
# Out:
# Pipeline(steps=[('encoding',
#                  ColumnTransformer(transformers=[('ohe',
#                                                   OneHotEncoder(sparse_output=False),
#                                                   ['country',
#                                                    'subscription_type',
#                                                    'payment_method',
#                                                    'preferred_category',
#                                                    'device_type']),
#                                                  ('oe', OrdinalEncoder(),
#                                                   ['gender', 'is_active',
#                                                    'campaign_response'])],
#                                    verbose_feature_names_out=False)),
#                 ('scaling', StandardScaler())])

# %%
scale_tf=[('ss',StandardScaler(),['age','total_spent','avg_session_duration']),
          ('MinMax',MinMaxScaler(),['purchase_count']),
          ('Robust',RobustScaler(),['credit_score'])]
scale_ct=ColumnTransformer(transformers=scale_tf, remainder='drop',verbose_feature_names_out=False).set_output(transform='pandas')

# %%
scale_ct
# Out:
# ColumnTransformer(transformers=[('ss', StandardScaler(),
#                                  ['age', 'total_spent',
#                                   'avg_session_duration']),
#                                 ('MinMax', MinMaxScaler(), ['purchase_count']),
#                                 ('Robust', RobustScaler(), ['credit_score'])],
#                   verbose_feature_names_out=False)

# %%
pipe2=Pipeline(steps=[('scaling', scale_ct)]).set_output(transform='pandas')

# %%
pipe1.fit_transform(df)
# Out:
#       country_Australia  country_Brazil  country_Canada  country_China  \
# 0             -0.309274       -0.298475       -0.300655      -0.306939
# 1             -0.309274       -0.298475       -0.300655      -0.306939
# 2             -0.309274       -0.298475       -0.300655      -0.306939
# 3             -0.309274       -0.298475       -0.300655      -0.306939
# 4             -0.309274       -0.298475       -0.300655      -0.306939
# ...                 ...             ...             ...            ...
# 9995          -0.309274       -0.298475       -0.300655      -0.306939
# 9996          -0.309274       -0.298475       -0.300655      -0.306939
# 9997          -0.309274       -0.298475       -0.300655      -0.306939
# 9998          -0.309274       -0.298475       -0.300655      -0.306939
# 9999          -0.309274       -0.298475       -0.300655      -0.306939
#
#       country_France  country_Germany  country_India  country_Japan  \
# ...

# %%
pipe2.fit_transform(df)
# Out:
#            age  total_spent  avg_session_duration  purchase_count  \
# 0    -0.250251    -0.920811              1.561425        0.505051
# 1    -0.452240    -1.427160             -0.923717        0.303030
# 2    -2.270141     1.288950             -1.704407        0.868687
# 3    -0.317581    -0.352484             -0.349880             NaN
# 4    -1.664174     2.421407                   NaN        0.333333
# ...        ...          ...                   ...             ...
# 9995 -0.317581     0.392581             -1.475811        0.979798
# 9996  0.221057     2.200197             -0.288668        0.969697
# 9997 -0.654229     2.913260                   NaN        0.050505
# 9998  0.961683     0.605145                   NaN        0.888889
# 9999 -0.317581     1.739458              0.938619        0.636364
#
#       credit_score
# 0        -0.253731
# 1        -0.305970
# 2        -0.186567
# 3        -0.619403
# 4        -0.037313
# ...            ...
# 9995      0.231343
# ...

# %%
fe=FeatureUnion(transformer_list=[('encode_tf',pipe1),('scale',pipe2)]).set_output(transform='pandas')

# %%
fe
# Out:
# FeatureUnion(transformer_list=[('encode_tf',
#                                 Pipeline(steps=[('encoding',
#                                                  ColumnTransformer(transformers=[('ohe',
#                                                                                   OneHotEncoder(sparse_output=False),
#                                                                                   ['country',
#                                                                                    'subscription_type',
#                                                                                    'payment_method',
#                                                                                    'preferred_category',
#                                                                                    'device_type']),
#                                                                                  ('oe',
# ...

# %%
df
# Out:
#       age gender     join_date last_purchase  total_spent  purchase_count  \
# 0      41      F  Dec 19, 2020    2025-04-02   238.517142            51.0
# 1      38      F    30/10/2021    2024-12-25    93.126377            31.0
# 2      11      M  May 03, 2022    2025-05-10   873.017713            87.0
# 3      40    NaN  Aug 03, 2021           NaN   401.703726             NaN
# 4      20      F  Apr 05, 2024    2025-05-07  1198.186419            34.0
# ...   ...    ...           ...           ...          ...             ...
# 9995   40      F    2020-07-14    2024-09-01   615.638525            98.0
# 9996   48      F    2022-10-24    2025-01-27  1134.668932            97.0
# 9997   35      F    07/01/2024    2024-12-07  1339.414613             6.0
# 9998   59    NaN  Sep 01, 2024    2025-03-13   676.673223            89.0
# 9999   40      F    2023-12-11    2024-08-23  1002.374697            64.0
#
#       country subscription_type  credit_score is_active  payment_method  \
# ...

# %%
simple_i=SimpleImputer(strategy='most_frequent')

# %%
simple_i
# Out:
# SimpleImputer(strategy='most_frequent')

# %%
X_imputed=simple_i.fit_transform(df[['country']])

# %%
X_imputed
# Out:
# array([['Germany'],
#        ['USA'],
#        ['Germany'],
#        ...,
#        ['USA'],
#        ['Japan'],
#        ['France']], dtype=object)

# %%
scaler=StandardScaler()

# %%
scaler
# Out:
# StandardScaler()

# %%
scaler_s=scaler.fit_transform(df[['purchase_count']])

# %%
scaler_s
# Out:
# array([[ 0.02085148],
#        [-0.66791256],
#        [ 1.26062674],
#        ...,
#        [-1.52886761],
#        [ 1.32950315],
#        [ 0.4685481 ]])

# %%
from sklearn.decomposition import PCA

# %%
pc=PCA()

# %%
df.isnull().sum()
# Out:
# age                        0
# gender                  1380
# join_date                  0
# last_purchase           1530
# total_spent                0
# purchase_count           941
# country                 1567
# subscription_type       2037
# credit_score               0
# is_active                  0
# payment_method          1671
# preferred_category      2125
# avg_session_duration    2023
# device_type                0
# campaign_response       1992
# dtype: int64

# %%
pc.fit_transform(df[['credit_score']])
# Out:
# array([[-32.745],
#        [-39.745],
#        [-23.745],
#        ...,
#        [154.255],
#        [-36.745],
#        [ 38.255]])

# %%
from sklearn.linear_model import LinearRegression

# %%
estimator=[
    ('simple_i', SimpleImputer()),
    ('standardScaler',StandardScaler()),
    ('pc', PCA()),
    ('regressor',LinearRegression())
    ]

# %%
from sklearn.linear_model import LinearRegression

# %%
pipe=Pipeline(steps=estimator)

# %%
pipe
# Out:
# Pipeline(steps=[('simple_i', SimpleImputer()),
#                 ('standardScaler', StandardScaler()), ('pc', PCA()),
#                 ('regressor', LinearRegression())])

# %%
pipe.steps[1]
# Out:
# ('standardScaler', StandardScaler())

# %%
pipe.named_steps.pc
# Out:
# PCA()

# %%
pipe[1]
# Out:
# StandardScaler()

# %%
pipe['pc']
# Out:
# PCA()

# %%
estimator=[
    ('simple_i', SimpleImputer()),
    ('standardScaler',StandardScaler()),
    ('pc', PCA()),
    ('regressor',LinearRegression())
    ]
pipe=Pipeline(steps=estimator)

# %%
pipe.set_params(pc__n_components=2)
# Out:
# Pipeline(steps=[('simple_i', SimpleImputer()),
#                 ('standardScaler', StandardScaler()),
#                 ('pc', PCA(n_components=2)),
#                 ('regressor', LinearRegression())])

# %%
from sklearn.impute import KNNImputer
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression

param_grid=dict(imputer=['passthrough',
                         SimpleImputer(),
                         KNNImputer()],
                clf=[SVC(), LogisticRegression()],
                clf_C=[0.1,10,100]
                )

# %%
param_grid
# Out:
# {'imputer': ['passthrough', SimpleImputer(), KNNImputer()],
#  'clf': [SVC(), LogisticRegression()],
#  'clf_C': [0.1, 10, 100]}

# %%
df
# Out:
#       age gender     join_date last_purchase  total_spent  purchase_count  \
# 0      41      F  Dec 19, 2020    2025-04-02   238.517142            51.0
# 1      38      F    30/10/2021    2024-12-25    93.126377            31.0
# 2      11      M  May 03, 2022    2025-05-10   873.017713            87.0
# 3      40    NaN  Aug 03, 2021           NaN   401.703726             NaN
# 4      20      F  Apr 05, 2024    2025-05-07  1198.186419            34.0
# ...   ...    ...           ...           ...          ...             ...
# 9995   40      F    2020-07-14    2024-09-01   615.638525            98.0
# 9996   48      F    2022-10-24    2025-01-27  1134.668932            97.0
# 9997   35      F    07/01/2024    2024-12-07  1339.414613             6.0
# 9998   59    NaN  Sep 01, 2024    2025-03-13   676.673223            89.0
# 9999   40      F    2023-12-11    2024-08-23  1002.374697            64.0
#
#       country subscription_type  credit_score is_active  payment_method  \
# ...

# %%
num_pipeline=Pipeline([('selector',ColumnTransformer([('select_first_4','passthrough',slice(0,4))])),
                       ('imputer',SimpleImputer(strategy='median')),
                       ('scale_s',StandardScaler())])

# %%
num_pipeline
# Out:
# Pipeline(steps=[('selector',
#                  ColumnTransformer(transformers=[('select_first_4',
#                                                   'passthrough',
#                                                   slice(0, 4, None))])),
#                 ('imputer', SimpleImputer(strategy='median')),
#                 ('scale_s', StandardScaler())])

# %%
from sklearn.preprocessing import LabelBinarizer
cat_pipeline=ColumnTransformer([('label_binarizer', LabelBinarizer(),[4])])

# %%
cat_pipeline
# Out:
# ColumnTransformer(transformers=[('label_binarizer', LabelBinarizer(), [4])])

# %%
fullPipeline=FeatureUnion(transformer_list=[('num_pipeline',num_pipeline),
                                            ('cat_pipeline',cat_pipeline)])

# %%
fullPipeline
# Out:
# FeatureUnion(transformer_list=[('num_pipeline',
#                                 Pipeline(steps=[('selector',
#                                                  ColumnTransformer(transformers=[('select_first_4',
#                                                                                   'passthrough',
#                                                                                   slice(0, 4, None))])),
#                                                 ('imputer',
#                                                  SimpleImputer(strategy='median')),
#                                                 ('scale_s',
#                                                  StandardScaler())])),
#                                ('cat_pipeline',
#                                 ColumnTransformer(transformers=[('label_binarizer',
#                                                                  LabelBinarizer(),
# ...

# %%
from sklearn.decomposition import PCA
from sklearn.impute import SimpleImputer
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import Pipeline
estimators = [
      ('simpleImputer', SimpleImputer()),
      ('pca', PCA()),
      ('regressor', LinearRegression())
  ]
pipe = Pipeline(steps=estimators)
print(len(pipe.steps))
# Out:
# 3

# %%
import numpy as np
from sklearn.preprocessing import add_dummy_feature
X=np.array([[1,4],[4,6]])
X_new=add_dummy_feature(X)
print(X_new)
# Out:
# [[1. 1. 4.]
#  [1. 4. 6.]]

# %%
from  sklearn.preprocessing import FunctionTransformer

# %%
ft=FunctionTransformer(np.log2)

# %%
ft.fit_transform(X)
# Out:
# array([[0.       , 2.       ],
#        [2.       , 2.5849625]])

# %%
import numpy as np
from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import SelectKBest, mutual_info_regression

X_california, y_california = fetch_california_housing(return_X_y=True)

X, y = X_california[:2000, :], y_california[:2000]
skb = SelectKBest(mutual_info_regression, k = 4)
X_new = skb.fit_transform(X,y)

# %%
X_new.shape
# Out:
# (2000, 4)

# %% [markdown]
# # WEEK 3    STARTS FROM HERE

# %%
d3=pd.read_csv('/content/Week3_GA_dataset.csv')

# %%
d3.head()
# Out:
#     V1    V2       V3    V4        V5 Target
# 0  2.0  50.0  12500.0  98.0  NEGATIVE    YES
# 1  0.0  13.0   3250.0  28.0  NEGATIVE    YES
# 2    ?     ?   4000.0  35.0  NEGATIVE    YES
# 3    ?  20.0   5000.0  45.0  NEGATIVE    YES
# 4  1.0  24.0   6000.0  77.0  NEGATIVE     NO

# %%
d3.shape
# Out:
# (748, 6)

# %%
d3['Target']
# Out:
# 0      YES
# 1      YES
# 2      YES
# 3      YES
# 4       NO
#       ...
# 743     NO
# 744     NO
# 745     NO
# 746     NO
# 747     NO
# Name: Target, Length: 748, dtype: object

# %%
d3.isnull().sum()
# Out:
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# Target    0
# dtype: int64

# %%
d3=d3.replace('?',np.nan)

# %%
d3.isnull().sum()
# Out:
# V1        5
# V2        5
# V3        0
# V4        0
# V5        0
# Target    0
# dtype: int64

# %%
d3.duplicated().sum()
# Out:
# np.int64(215)

# %%
import sklearn
print(sklearn.__version__)
# Out:
# 1.6.1

# %%
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OrdinalEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn.compose import ColumnTransformer
from sklearn.feature_selection import VarianceThreshold
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression

# %%
num_imputer=['V1','V2','V3','V4']
estimator=[('si',SimpleImputer(strategy='mean')),('sc',StandardScaler())]
pipe1=Pipeline(steps=estimator)

# %%
pipe1
# Out:
# Pipeline(steps=[('si', SimpleImputer()), ('sc', StandardScaler())])

# %%
cat_imputer=['V5']
estimator=[('Ord',OrdinalEncoder())]
pipe2=Pipeline(steps=estimator)

# %%
pipe2
# Out:
# Pipeline(steps=[('Ord', OrdinalEncoder())])

# %%
preprocessor=ColumnTransformer([('num',pipe1,num_imputer),('cat',pipe2,cat_imputer)])

# %%
preprocessor
# Out:
# ColumnTransformer(transformers=[('num',
#                                  Pipeline(steps=[('si', SimpleImputer()),
#                                                  ('sc', StandardScaler())]),
#                                  ['V1', 'V2', 'V3', 'V4']),
#                                 ('cat',
#                                  Pipeline(steps=[('Ord', OrdinalEncoder())]),
#                                  ['V5'])])

# %%
model=LogisticRegression()
rfe=RFE(estimator=model,n_features_to_select=2)


full_pipeline=Pipeline([
    ('preprocessor',preprocessor),
    ('feature_selector',rfe)
])

# %%
full_pipeline
# Answer 1 Week 3 graded
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('si',
#                                                                    SimpleImputer()),
#                                                                   ('sc',
#                                                                    StandardScaler())]),
#                                                   ['V1', 'V2', 'V3', 'V4']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('Ord',
#                                                                    OrdinalEncoder())]),
#                                                   ['V5'])])),
#                 ('feature_selector',
#                  RFE(estimator=LogisticRegression(), n_features_to_select=2))])

# %%
X_preprocessed=d3[['V1','V2','V3','V4','V5']]

# %%
Y=pipe2.fit_transform(d3[['Target']])

# %%
print(d3['Target'].value_counts())
# Out:
# Target
# NO     570
# YES    178
# Name: count, dtype: int64

# %%
full_pipeline.fit(X_preprocessed,Y)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %%
rfe_selector=full_pipeline.named_steps['feature_selector']

# %%
rfe_selector
# Out:
# RFE(estimator=LogisticRegression(), n_features_to_select=2)

# %%
selected_mask=rfe_selector.support_

# %%
selected_mask
# Out:
# array([ True, False,  True, False, False])

# %%
all_features=['V1','V2','V3','V4','V5']

# %%
top_features=[f for f,s in zip(all_features, selected_mask) if s]

# %%
# Answer 2 Week 3 Grdaded
print(top_features)
# Out:
# ['V1', 'V3']

# %%
fullPipeline=FeatureUnion(transformer_list=[('num_pipeline',num_pipeline),
                                            ('cat_pipeline',cat_pipeline)])

# %%
pipe1
# Out:
# Pipeline(steps=[('si', SimpleImputer()), ('sc', StandardScaler())])

# %%
pipe2
# Out:
# Pipeline(steps=[('Ord', OrdinalEncoder())])

# %%
fulpipeline=FeatureUnion(transformer_list=[('pipe1',pipe1),('pipe2',pipe2)])

# %%
fulpipeline
# Out:
# FeatureUnion(transformer_list=[('pipe1',
#                                 Pipeline(steps=[('si', SimpleImputer()),
#                                                 ('sc', StandardScaler())])),
#                                ('pipe2',
#                                 Pipeline(steps=[('Ord', OrdinalEncoder())]))])

# %%
from sklearn.preprocessing import LabelEncoder

# %%
 y_encoded = pd.Series(LabelEncoder().fit_transform(d3['Target']), dtype=np.uint8)
 y_encoded.head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    0
# dtype: uint8

# %%
X_copy=d3[['V1','V2','V3','V4','V5']]

# %%
 from sklearn.feature_selection import VarianceThreshold, RFE, SequentialFeatureSelector

# %%
sfs = SequentialFeatureSelector(
    LogisticRegression(),
    n_features_to_select=2
)

# %%
sfs
# Out:
# SequentialFeatureSelector(estimator=LogisticRegression(),
#                           n_features_to_select=2)

# %%
full_pipeline_sfs = Pipeline([
    ('preprocessor', preprocessor),
    ('feature_selector', sfs)
])

# %%
full_pipeline_sfs
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('si',
#                                                                    SimpleImputer()),
#                                                                   ('sc',
#                                                                    StandardScaler())]),
#                                                   ['V1', 'V2', 'V3', 'V4']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('Ord',
#                                                                    OrdinalEncoder())]),
#                                                   ['V5'])])),
#                 ('feature_selector',
#                  SequentialFeatureSelector(estimator=LogisticRegression(),
#                                            n_features_to_select=2))])

# %%
full_pipeline_sfs.fit(X_copy, y_encoded)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('si',
#                                                                    SimpleImputer()),
#                                                                   ('sc',
#                                                                    StandardScaler())]),
#                                                   ['V1', 'V2', 'V3', 'V4']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('Ord',
#                                                                    OrdinalEncoder())]),
#                                                   ['V5'])])),
#                 ('feature_selector',
#                  SequentialFeatureSelector(estimator=LogisticRegression(),
#                                            n_features_to_select=2))])

# %%
# Answer 3 Week 3 graded
X_copy.iloc[:, sfs.support_].columns
# Out:
# Index(['V2', 'V4'], dtype='object')

# %%
sfs_back = SequentialFeatureSelector(
    LogisticRegression(),
    n_features_to_select=2,
    direction='backward'
)

# %%
full_pipeline_sfs_back = Pipeline([
    ('preprocessor', preprocessor),
    ('feature_selector', sfs_back)
])

# %%
full_pipeline_sfs_back
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('si',
#                                                                    SimpleImputer()),
#                                                                   ('sc',
#                                                                    StandardScaler())]),
#                                                   ['V1', 'V2', 'V3', 'V4']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('Ord',
#                                                                    OrdinalEncoder())]),
#                                                   ['V5'])])),
#                 ('feature_selector',
#                  SequentialFeatureSelector(direction='backward',
#                                            estimator=LogisticRegression(),
# ...

# %%
full_pipeline_sfs_back.fit(X_copy,y_encoded)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('si',
#                                                                    SimpleImputer()),
#                                                                   ('sc',
#                                                                    StandardScaler())]),
#                                                   ['V1', 'V2', 'V3', 'V4']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('Ord',
#                                                                    OrdinalEncoder())]),
#                                                   ['V5'])])),
#                 ('feature_selector',
#                  SequentialFeatureSelector(direction='backward',
#                                            estimator=LogisticRegression(),
# ...

# %%
# Answers 4 week 3 graaded
X_copy.iloc[:, sfs_back.support_].columns
# Out:
# Index(['V3', 'V4'], dtype='object')
